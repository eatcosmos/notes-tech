# %% [markdown]
# 比赛地址 https://tianchi.aliyun.com/competition/entrance/531830/introduction
# 学习中遇到的问题可以登记在《答疑手册》 https://shimo.im/docs/Bjaazvhols4ynJzo
# sample_submit.csv
# train.csv
# testA.csv
# [【宝可梦数据分析\-平民最强宝可梦系列】\-天池实验室\-阿里云天池](https://tianchi.aliyun.com/notebook-ai/detail?spm=5176.19700039.J_3678908510.12.68f13ff4mLEJ7w&postId=125735)
# !wget -O pokemon_data.csv https://pai-public-data.oss-cn-beijing.aliyuncs.com/pokemon/pokemon.csv
